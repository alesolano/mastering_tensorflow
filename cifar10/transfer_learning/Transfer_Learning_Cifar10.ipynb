# %% [markdown]
# # Transfer Learning
#
# Most of the time you won't want to train a whole convolutional network yourself. Modern ConvNets training on huge datasets like ImageNet take weeks on multiple GPUs. Instead, most people use a pretrained network either as a fixed feature extractor, or as an initial network to fine tune. In this notebook, you'll be using [VGGNet](https://arxiv.org/pdf/1409.1556.pdf) trained on the [ImageNet dataset](http://www.image-net.org/) as a feature extractor. Below is a diagram of the VGGNet architecture.
#
# <img src="assets/cnnarchitecture.jpg" width=700px>
#
# VGGNet is great because it's simple and has great performance, coming in second in the ImageNet competition. The idea here is that we keep all the convolutional layers, but replace the final fully connected layers with our own classifier. This way we can use VGGNet as a feature extractor for our images then easily train a simple classifier on top of that. What we'll do is take the first fully connected layer with 4096 units, including thresholding with ReLUs. We can use those values as a code for each image, then build a classifier on top of those codes.
#
# You can read more about transfer learning from [the CS231n course notes](http://cs231n.github.io/transfer-learning/#tf).
#
# ## Pretrained VGGNet
#
# We'll be using a pretrained network from https://github.com/machrisaa/tensorflow-vgg.
#
# This is a really nice implementation of VGGNet, quite easy to work with. The network has already been trained and the parameters are available from this link.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm

vgg_dir = 'tensorflow_vgg/'
# Make sure vgg exists
if not isdir(vgg_dir):
    raise Exception("VGG directory doesn't exist!")

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(vgg_dir + "vgg16.npy"):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='VGG16 Parameters') as pbar:
        urlretrieve(
            'https://s3.amazonaws.com/content.udacity-data.com/nd101/vgg16.npy',
            vgg_dir + 'vgg16.npy',
            pbar.hook)
else:
    print("Parameter file already exists!")
# Out:
# VGG16 Parameters: 553MB [00:33, 16.3MB/s]

# %% [markdown]
# ## Flower power
#
# Here we'll be using VGGNet to classify images of flowers. To get the flower dataset, run the cell below. This dataset comes from the [TensorFlow inception tutorial](https://www.tensorflow.org/tutorials/image_retraining).

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()
        
print('All files found!')
# Out:
# CIFAR-10 Dataset: 171MB [03:26, 827KB/s]
# All files found!

# %% [markdown]
# ## ConvNet Codes
#
# Below, we'll run through all the images in our dataset and get codes for each of them. That is, we'll run the images through the VGGNet convolutional layers and record the values of the first fully connected layer. We can then write these to a file for later when we build our own classifier.
#
# Here we're using the `vgg16` module from `tensorflow_vgg`. The network takes images of size $244 \times 224 \times 3$ as input. Then it has 5 sets of convolutional layers. The network implemented here has this structure (copied from [the source code](https://github.com/machrisaa/tensorflow-vgg/blob/master/vgg16.py):
#
# ```
# self.conv1_1 = self.conv_layer(bgr, "conv1_1")
# self.conv1_2 = self.conv_layer(self.conv1_1, "conv1_2")
# self.pool1 = self.max_pool(self.conv1_2, 'pool1')
#
# self.conv2_1 = self.conv_layer(self.pool1, "conv2_1")
# self.conv2_2 = self.conv_layer(self.conv2_1, "conv2_2")
# self.pool2 = self.max_pool(self.conv2_2, 'pool2')
#
# self.conv3_1 = self.conv_layer(self.pool2, "conv3_1")
# self.conv3_2 = self.conv_layer(self.conv3_1, "conv3_2")
# self.conv3_3 = self.conv_layer(self.conv3_2, "conv3_3")
# self.pool3 = self.max_pool(self.conv3_3, 'pool3')
#
# self.conv4_1 = self.conv_layer(self.pool3, "conv4_1")
# self.conv4_2 = self.conv_layer(self.conv4_1, "conv4_2")
# self.conv4_3 = self.conv_layer(self.conv4_2, "conv4_3")
# self.pool4 = self.max_pool(self.conv4_3, 'pool4')
#
# self.conv5_1 = self.conv_layer(self.pool4, "conv5_1")
# self.conv5_2 = self.conv_layer(self.conv5_1, "conv5_2")
# self.conv5_3 = self.conv_layer(self.conv5_2, "conv5_3")
# self.pool5 = self.max_pool(self.conv5_3, 'pool5')
#
# self.fc6 = self.fc_layer(self.pool5, "fc6")
# self.relu6 = tf.nn.relu(self.fc6)
# ```
#
# So what we want are the values of the first fully connected layer, after being ReLUd (`self.relu6`). To build the network, we use
#
# ```
# with tf.Session() as sess:
#     vgg = vgg16.Vgg16()
#     input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
#     with tf.name_scope("content_vgg"):
#         vgg.build(input_)
# ```
#
# This creates the `vgg` object, then builds the graph with `vgg.build(input_)`. Then to get the values from the layer,
#
# ```
# feed_dict = {input_: images}
# codes = sess.run(vgg.relu6, feed_dict=feed_dict)
# ```

# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg16
from tensorflow_vgg import utils

# %%
def normalize(inputs):
    """
    Get inputs with zero mean and standard deviation of 1.0.
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    inputs = inputs.astype(float)
    norm_inputs = np.copy(inputs)
    for i in range(len(inputs)):
        mean = np.mean(inputs[i])
        # Use adjusted standard deviation here, in case the std == 0.
        std = np.maximum(np.std(inputs[i]), 1.0/np.sqrt(inputs.shape[1] * inputs.shape[2] * inputs.shape[3]))
        norm_inputs[i] = (inputs[i] - mean) / std
    return norm_inputs

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer().fit(range(10))

def one_hot_encode(labels):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    one_hot_labels = lb.transform(labels)
    return one_hot_labels

# %%
import helper

helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %%
#data_dir = 'flower_photos/'
#contents = os.listdir(data_dir)
#classes = [each for each in contents if os.path.isdir(data_dir + each)]

# %% [markdown]
# Below I'm running images through the VGG network in batches.

# %%
# Set the batch size higher if you can fit in in your GPU memory
import skimage.transform

batch_size = 10
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:
    vgg = vgg16.Vgg16()
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)
        
    count = 0
    n_batches = 5
    for batch_i in range(1, n_batches + 1):
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            for image, label in zip(batch_features, batch_labels):
                resized_img = skimage.transform.resize(image, (224, 224), mode='constant')
                batch.append(resized_img.reshape((1, 224, 224, 3)))
                labels.append(label)
            
                
            images = np.concatenate(batch)

            feed_dict = {input_: images}
            codes_batch = sess.run(vgg.relu6, feed_dict=feed_dict)
                
            # Here I'm building an array of the codes
            if codes is None:
                codes = codes_batch
            else:
                codes = np.concatenate((codes, codes_batch))
            
            # Reset to start building the next batch
            batch = []
            
            count += batch_features.shape[0]
            print('{} images processed'.format(count))
# Out:
# /home/carnd/deep-learning/transfer-learning/tensorflow_vgg/vgg16.npy
# npy file loaded
# build model started
# build model finished: 0s
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# 420 images processed
# 430 images processed
# 440 images processed
# 450 images processed
# 460 images processed
# 470 images processed
# 480 images processed
# 490 images processed
# 500 images processed
# 510 images processed
# 520 images processed
# 530 images processed
# 540 images processed
# 550 images processed
# 560 images processed
# 570 images processed
# 580 images processed
# 590 images processed
# 600 images processed
# 610 images processed
# 620 images processed
# 630 images processed
# 640 images processed
# 650 images processed
# 660 images processed
# 670 images processed
# 680 images processed
# 690 images processed
# 700 images processed
# 710 images processed
# 720 images processed
# 730 images processed
# 740 images processed
# 750 images processed
# 760 images processed
# 770 images processed
# 780 images processed
# 790 images processed
# 800 images processed
# 810 images processed
# 820 images processed
# 830 images processed
# 840 images processed
# 850 images processed
# 860 images processed
# 870 images processed
# 880 images processed
# 890 images processed
# 900 images processed
# 910 images processed
# 920 images processed
# 930 images processed
# 940 images processed
# 950 images processed
# 960 images processed
# 970 images processed
# 980 images processed
# 990 images processed
# 1000 images processed
# 1010 images processed
# 1020 images processed
# 1030 images processed
# 1040 images processed
# 1050 images processed
# 1060 images processed
# 1070 images processed
# 1080 images processed
# 1090 images processed
# 1100 images processed
# 1110 images processed
# 1120 images processed
# 1130 images processed
# 1140 images processed
# 1150 images processed
# 1160 images processed
# 1170 images processed
# 1180 images processed
# 1190 images processed
# 1200 images processed
# 1210 images processed
# 1220 images processed
# 1230 images processed
# 1240 images processed
# 1250 images processed
# 1260 images processed
# 1270 images processed
# 1280 images processed
# 1290 images processed
# 1300 images processed
# 1310 images processed
# 1320 images processed
# 1330 images processed
# 1340 images processed
# 1350 images processed
# 1360 images processed
# 1370 images processed
# 1380 images processed
# 1390 images processed
# 1400 images processed
# 1410 images processed
# 1420 images processed
# 1430 images processed
# 1440 images processed
# 1450 images processed
# 1460 images processed
# 1470 images processed
# 1480 images processed
# 1490 images processed
# 1500 images processed
# 1510 images processed
# 1520 images processed
# 1530 images processed
# 1540 images processed
# 1550 images processed
# 1560 images processed
# 1570 images processed
# 1580 images processed
# 1590 images processed
# 1600 images processed
# 1610 images processed
# 1620 images processed
# 1630 images processed
# 1640 images processed
# 1650 images processed
# 1660 images processed
# 1670 images processed
# 1680 images processed
# 1690 images processed
# 1700 images processed
# 1710 images processed
# 1720 images processed
# 1730 images processed
# 1740 images processed
# 1750 images processed
# 1760 images processed
# 1770 images processed
# 1780 images processed
# 1790 images processed
# 1800 images processed
# 1810 images processed
# 1820 images processed
# 1830 images processed
# 1840 images processed
# 1850 images processed
# 1860 images processed
# 1870 images processed
# 1880 images processed
# 1890 images processed
# 1900 images processed
# 1910 images processed
# 1920 images processed
# 1930 images processed
# 1940 images processed
# 1950 images processed
# 1960 images processed
# 1970 images processed
# 1980 images processed
# 1990 images processed
# 2000 images processed
# 2010 images processed
# 2020 images processed
# 2030 images processed
# 2040 images processed
# 2050 images processed
# 2060 images processed
# 2070 images processed
# 2080 images processed
# 2090 images processed
# 2100 images processed
# 2110 images processed
# 2120 images processed
# 2130 images processed
# 2140 images processed
# 2150 images processed
# 2160 images processed
# 2170 images processed
# 2180 images processed
# 2190 images processed
# 2200 images processed
# 2210 images processed
# 2220 images processed
# 2230 images processed
# 2240 images processed
# 2250 images processed
# 2260 images processed
# 2270 images processed
# 2280 images processed
# 2290 images processed
# 2300 images processed
# 2310 images processed
# 2320 images processed
# 2330 images processed
# 2340 images processed
# 2350 images processed
# 2360 images processed
# 2370 images processed
# 2380 images processed
# 2390 images processed
# 2400 images processed
# 2410 images processed
# 2420 images processed
# 2430 images processed
# 2440 images processed
# 2450 images processed
# 2460 images processed
# 2470 images processed
# 2480 images processed
# 2490 images processed
# 2500 images processed
# 2510 images processed
# 2520 images processed
# 2530 images processed
# 2540 images processed
# 2550 images processed
# 2560 images processed
# 2570 images processed
# 2580 images processed
# 2590 images processed
# 2600 images processed
# 2610 images processed
# 2620 images processed
# 2630 images processed
# 2640 images processed
# 2650 images processed
# 2660 images processed
# 2670 images processed
# 2680 images processed
# 2690 images processed
# 2700 images processed
# 2710 images processed
# 2720 images processed
# 2730 images processed
# 2740 images processed
# 2750 images processed
# 2760 images processed
# 2770 images processed
# 2780 images processed
# 2790 images processed
# 2800 images processed
# 2810 images processed
# 2820 images processed
# 2830 images processed
# 2840 images processed
# 2850 images processed
# 2860 images processed
# 2870 images processed
# 2880 images processed
# 2890 images processed
# 2900 images processed
# 2910 images processed
# 2920 images processed
# 2930 images processed
# 2940 images processed
# 2950 images processed
# 2960 images processed
# 2970 images processed
# 2980 images processed
# 2990 images processed
# 3000 images processed
# 3010 images processed
# 3020 images processed
# 3030 images processed
# 3040 images processed
# 3050 images processed
# 3060 images processed
# 3070 images processed
# 3080 images processed
# 3090 images processed
# 3100 images processed
# 3110 images processed
# 3120 images processed
# 3130 images processed
# 3140 images processed
# 3150 images processed
# 3160 images processed
# 3170 images processed
# 3180 images processed
# 3190 images processed
# 3200 images processed
# 3210 images processed
# 3220 images processed
# 3230 images processed
# 3240 images processed
# 3250 images processed
# 3260 images processed
# 3270 images processed
# 3280 images processed
# 3290 images processed
# 3300 images processed
# 3310 images processed
# 3320 images processed
# 3330 images processed
# 3340 images processed
# 3350 images processed
# 3360 images processed
# 3370 images processed
# 3380 images processed
# 3390 images processed
# 3400 images processed
# 3410 images processed
# 3420 images processed
# 3430 images processed
# 3440 images processed
# 3450 images processed
# 3460 images processed
# 3470 images processed
# 3480 images processed
# 3490 images processed
# 3500 images processed
# 3510 images processed
# 3520 images processed
# 3530 images processed
# 3540 images processed
# 3550 images processed
# 3560 images processed
# 3570 images processed
# 3580 images processed
# 3590 images processed
# 3600 images processed
# 3610 images processed
# 3620 images processed
# 3630 images processed
# 3640 images processed
# 3650 images processed
# 3660 images processed
# 3670 images processed
# 3680 images processed
# 3690 images processed
# 3700 images processed
# 3710 images processed
# 3720 images processed
# 3730 images processed
# 3740 images processed
# 3750 images processed
# 3760 images processed
# 3770 images processed
# 3780 images processed
# 3790 images processed
# 3800 images processed
# 3810 images processed
# 3820 images processed
# 3830 images processed
# 3840 images processed
# 3850 images processed
# 3860 images processed
# 3870 images processed
# 3880 images processed
# 3890 images processed
# 3900 images processed
# 3910 images processed
# 3920 images processed
# 3930 images processed
# 3940 images processed
# 3950 images processed
# 3960 images processed
# 3970 images processed
# 3980 images processed
# 3990 images processed
# 4000 images processed
# 4010 images processed
# 4020 images processed
# 4030 images processed
# 4040 images processed
# 4050 images processed
# 4060 images processed
# 4070 images processed
# 4080 images processed
# 4090 images processed
# 4100 images processed
# 4110 images processed
# 4120 images processed
# 4130 images processed
# 4140 images processed
# 4150 images processed
# 4160 images processed
# 4170 images processed
# 4180 images processed
# 4190 images processed
# 4200 images processed
# 4210 images processed
# 4220 images processed
# 4230 images processed
# 4240 images processed
# 4250 images processed
# 4260 images processed
# 4270 images processed
# 4280 images processed
# 4290 images processed
# 4300 images processed
# 4310 images processed
# 4320 images processed
# 4330 images processed
# 4340 images processed
# 4350 images processed
# 4360 images processed
# 4370 images processed
# 4380 images processed
# 4390 images processed
# 4400 images processed
# 4410 images processed
# 4420 images processed
# 4430 images processed
# 4440 images processed
# 4450 images processed
# 4460 images processed
# 4470 images processed
# 4480 images processed
# 4490 images processed
# 4500 images processed
# 4510 images processed
# 4520 images processed
# 4530 images processed
# 4540 images processed
# 4550 images processed
# 4560 images processed
# 4570 images processed
# 4580 images processed
# 4590 images processed
# 4600 images processed
# 4610 images processed
# 4620 images processed
# 4630 images processed
# 4640 images processed
# 4650 images processed
# 4660 images processed
# 4670 images processed
# 4680 images processed
# 4690 images processed
# 4700 images processed
# 4710 images processed
# 4720 images processed
# 4730 images processed
# 4740 images processed
# 4750 images processed
# 4760 images processed
# 4770 images processed
# 4780 images processed
# 4790 images processed
# 4800 images processed
# 4810 images processed
# 4820 images processed
# 4830 images processed
# 4840 images processed
# 4850 images processed
# 4860 images processed
# 4870 images processed
# 4880 images processed
# 4890 images processed
# 4900 images processed
# 4910 images processed
# 4920 images processed
# 4930 images processed
# 4940 images processed
# 4950 images processed
# 4960 images processed
# 4970 images processed
# 4980 images processed
# 4990 images processed
# 5000 images processed
# 5010 images processed
# 5020 images processed
# 5030 images processed
# 5040 images processed
# 5050 images processed
# 5060 images processed
# 5070 images processed
# 5080 images processed
# 5090 images processed
# 5100 images processed
# 5110 images processed
# 5120 images processed
# 5130 images processed
# 5140 images processed
# 5150 images processed
# 5160 images processed
# 5170 images processed
# 5180 images processed
# 5190 images processed
# 5200 images processed
# 5210 images processed
# 5220 images processed
# 5230 images processed
# 5240 images processed
# 5250 images processed
# 5260 images processed
# 5270 images processed
# 5280 images processed
# 5290 images processed
# 5300 images processed
# 5310 images processed
# 5320 images processed
# 5330 images processed
# 5340 images processed
# 5350 images processed
# 5360 images processed
# 5370 images processed
# 5380 images processed
# 5390 images processed
# 5400 images processed
# 5410 images processed
# 5420 images processed
# 5430 images processed
# 5440 images processed
# 5450 images processed
# 5460 images processed
# 5470 images processed
# 5480 images processed
# 5490 images processed
# 5500 images processed
# 5510 images processed
# 5520 images processed
# 5530 images processed
# 5540 images processed
# 5550 images processed
# 5560 images processed
# 5570 images processed
# 5580 images processed
# 5590 images processed
# 5600 images processed
# 5610 images processed
# 5620 images processed
# 5630 images processed
# 5640 images processed
# 5650 images processed
# 5660 images processed
# 5670 images processed
# 5680 images processed
# 5690 images processed
# 5700 images processed
# 5710 images processed
# 5720 images processed
# 5730 images processed
# 5740 images processed
# 5750 images processed
# 5760 images processed
# 5770 images processed
# 5780 images processed
# 5790 images processed
# 5800 images processed
# 5810 images processed
# 5820 images processed
# 5830 images processed
# 5840 images processed
# 5850 images processed
# 5860 images processed
# 5870 images processed
# 5880 images processed
# 5890 images processed
# 5900 images processed
# 5910 images processed
# 5920 images processed
# 5930 images processed
# 5940 images processed
# 5950 images processed
# 5960 images processed
# 5970 images processed
# 5980 images processed
# 5990 images processed
# 6000 images processed
# 6010 images processed
# 6020 images processed
# 6030 images processed
# 6040 images processed
# 6050 images processed
# 6060 images processed
# 6070 images processed
# 6080 images processed
# 6090 images processed
# 6100 images processed
# 6110 images processed
# 6120 images processed
# 6130 images processed
# 6140 images processed
# 6150 images processed
# 6160 images processed
# 6170 images processed
# 6180 images processed
# 6190 images processed
# 6200 images processed
# 6210 images processed
# 6220 images processed
# 6230 images processed
# 6240 images processed
# 6250 images processed
# 6260 images processed
# 6270 images processed
# 6280 images processed
# 6290 images processed
# 6300 images processed
# 6310 images processed
# 6320 images processed
# 6330 images processed
# 6340 images processed
# 6350 images processed
# 6360 images processed
# 6370 images processed
# 6380 images processed
# 6390 images processed
# 6400 images processed
# 6410 images processed
# 6420 images processed
# 6430 images processed
# 6440 images processed
# 6450 images processed
# 6460 images processed
# 6470 images processed
# 6480 images processed
# 6490 images processed
# 6500 images processed
# 6510 images processed
# 6520 images processed
# 6530 images processed
# 6540 images processed
# 6550 images processed
# 6560 images processed
# 6570 images processed
# 6580 images processed
# 6590 images processed
# 6600 images processed
# 6610 images processed
# 6620 images processed
# 6630 images processed
# 6640 images processed
# 6650 images processed
# 6660 images processed
# 6670 images processed
# 6680 images processed
# 6690 images processed
# 6700 images processed
# 6710 images processed
# 6720 images processed
# 6730 images processed
# 6740 images processed
# 6750 images processed
# 6760 images processed
# 6770 images processed
# 6780 images processed
# 6790 images processed
# 6800 images processed
# 6810 images processed
# 6820 images processed
# 6830 images processed
# 6840 images processed
# 6850 images processed
# 6860 images processed
# 6870 images processed
# 6880 images processed
# 6890 images processed
# 6900 images processed
# 6910 images processed
# 6920 images processed
# 6930 images processed
# 6940 images processed
# 6950 images processed
# 6960 images processed
# 6970 images processed
# 6980 images processed
# 6990 images processed
# 7000 images processed
# 7010 images processed
# 7020 images processed
# 7030 images processed
# 7040 images processed
# 7050 images processed
# 7060 images processed
# 7070 images processed
# 7080 images processed
# 7090 images processed
# 7100 images processed
# 7110 images processed
# 7120 images processed
# 7130 images processed
# 7140 images processed
# 7150 images processed
# 7160 images processed
# 7170 images processed
# 7180 images processed
# 7190 images processed
# 7200 images processed
# 7210 images processed
# 7220 images processed
# 7230 images processed
# 7240 images processed
# 7250 images processed
# 7260 images processed
# 7270 images processed
# 7280 images processed
# 7290 images processed
# 7300 images processed
# 7310 images processed
# 7320 images processed
# 7330 images processed
# 7340 images processed
# 7350 images processed
# 7360 images processed
# 7370 images processed
# 7380 images processed
# 7390 images processed
# 7400 images processed
# 7410 images processed
# 7420 images processed
# 7430 images processed
# 7440 images processed
# 7450 images processed
# 7460 images processed
# 7470 images processed
# 7480 images processed
# 7490 images processed
# 7500 images processed
# 7510 images processed
# 7520 images processed
# 7530 images processed
# 7540 images processed
# 7550 images processed
# 7560 images processed
# 7570 images processed
# 7580 images processed
# 7590 images processed
# 7600 images processed
# 7610 images processed
# 7620 images processed
# 7630 images processed
# 7640 images processed
# 7650 images processed
# 7660 images processed
# 7670 images processed
# 7680 images processed
# 7690 images processed
# 7700 images processed
# 7710 images processed
# 7720 images processed
# 7730 images processed
# 7740 images processed
# 7750 images processed
# 7760 images processed
# 7770 images processed
# 7780 images processed
# 7790 images processed
# 7800 images processed
# 7810 images processed
# 7820 images processed
# 7830 images processed
# 7840 images processed
# 7850 images processed
# 7860 images processed
# 7870 images processed
# 7880 images processed
# 7890 images processed
# 7900 images processed
# 7910 images processed
# 7920 images processed
# 7930 images processed
# 7940 images processed
# 7950 images processed
# 7960 images processed
# 7970 images processed
# 7980 images processed
# 7990 images processed
# 8000 images processed
# 8010 images processed
# 8020 images processed
# 8030 images processed
# 8040 images processed
# 8050 images processed
# 8060 images processed
# 8070 images processed
# 8080 images processed
# 8090 images processed
# 8100 images processed
# 8110 images processed
# 8120 images processed
# 8130 images processed
# 8140 images processed
# 8150 images processed
# 8160 images processed
# 8170 images processed
# 8180 images processed
# 8190 images processed
# 8200 images processed
# 8210 images processed
# 8220 images processed
# 8230 images processed
# 8240 images processed
# 8250 images processed
# 8260 images processed
# 8270 images processed
# 8280 images processed
# 8290 images processed
# 8300 images processed
# 8310 images processed
# 8320 images processed
# 8330 images processed
# 8340 images processed
# 8350 images processed
# 8360 images processed
# 8370 images processed
# 8380 images processed
# 8390 images processed
# 8400 images processed
# 8410 images processed
# 8420 images processed
# 8430 images processed
# 8440 images processed
# 8450 images processed
# 8460 images processed
# 8470 images processed
# 8480 images processed
# 8490 images processed
# 8500 images processed
# 8510 images processed
# 8520 images processed
# 8530 images processed
# 8540 images processed
# 8550 images processed
# 8560 images processed
# 8570 images processed
# 8580 images processed
# 8590 images processed
# 8600 images processed
# 8610 images processed
# 8620 images processed
# 8630 images processed
# 8640 images processed
# 8650 images processed
# 8660 images processed
# 8670 images processed
# 8680 images processed
# 8690 images processed
# 8700 images processed
# 8710 images processed
# 8720 images processed
# 8730 images processed
# 8740 images processed
# 8750 images processed
# 8760 images processed
# 8770 images processed
# 8780 images processed
# 8790 images processed
# 8800 images processed
# 8810 images processed
# 8820 images processed
# 8830 images processed
# 8840 images processed
# 8850 images processed
# 8860 images processed
# 8870 images processed
# 8880 images processed
# 8890 images processed
# 8900 images processed
# 8910 images processed
# 8920 images processed
# 8930 images processed
# 8940 images processed
# 8950 images processed
# 8960 images processed
# 8970 images processed
# 8980 images processed
# 8990 images processed
# 9000 images processed
# 9010 images processed
# 9020 images processed
# 9030 images processed
# 9040 images processed
# 9050 images processed
# 9060 images processed
# 9070 images processed
# 9080 images processed
# 9090 images processed
# 9100 images processed
# 9110 images processed
# 9120 images processed
# 9130 images processed
# 9140 images processed
# 9150 images processed
# 9160 images processed
# 9170 images processed
# 9180 images processed
# 9190 images processed
# 9200 images processed
# 9210 images processed
# 9220 images processed
# 9230 images processed
# 9240 images processed
# 9250 images processed
# 9260 images processed
# 9270 images processed
# 9280 images processed
# 9290 images processed
# 9300 images processed
# 9310 images processed
# 9320 images processed
# 9330 images processed
# 9340 images processed
# 9350 images processed
# 9360 images processed
# 9370 images processed
# 9380 images processed
# 9390 images processed
# 9400 images processed
# 9410 images processed
# 9420 images processed
# 9430 images processed
# 9440 images processed
# 9450 images processed
# 9460 images processed
# 9470 images processed
# 9480 images processed
# 9490 images processed
# 9500 images processed
# 9510 images processed
# 9520 images processed
# 9530 images processed
# 9540 images processed
# 9550 images processed
# 9560 images processed
# 9570 images processed
# 9580 images processed
# 9590 images processed
# 9600 images processed
# 9610 images processed
# 9620 images processed
# 9630 images processed
# 9640 images processed
# 9650 images processed
# 9660 images processed
# 9670 images processed
# 9680 images processed
# 9690 images processed
# 9700 images processed
# 9710 images processed
# 9720 images processed
# 9730 images processed
# 9740 images processed
# 9750 images processed
# 9760 images processed
# 9770 images processed
# 9780 images processed
# 9790 images processed
# 9800 images processed
# 9810 images processed
# 9820 images processed
# 9830 images processed
# 9840 images processed
# 9850 images processed
# 9860 images processed
# 9870 images processed
# 9880 images processed
# 9890 images processed
# 9900 images processed
# 9910 images processed
# 9920 images processed
# 9930 images processed
# 9940 images processed
# 9950 images processed
# 9960 images processed
# 9970 images processed
# 9980 images processed
# 9990 images processed
# 10000 images processed
# 10010 images processed
# 10020 images processed
# 10030 images processed
# 10040 images processed
# 10050 images processed
# 10060 images processed
# 10070 images processed
# 10080 images processed
# 10090 images processed
# 10100 images processed
# 10110 images processed
# 10120 images processed
# 10130 images processed
# 10140 images processed
# 10150 images processed
# 10160 images processed
# 10170 images processed
# 10180 images processed
# 10190 images processed
# 10200 images processed
# 10210 images processed
# 10220 images processed
# 10230 images processed
# 10240 images processed
# 10250 images processed
# 10260 images processed
# 10270 images processed
# 10280 images processed
# 10290 images processed
# 10300 images processed
# 10310 images processed
# 10320 images processed
# 10330 images processed
# 10340 images processed
# 10350 images processed
# 10360 images processed
# 10370 images processed
# 10380 images processed
# 10390 images processed
# 10400 images processed
# 10410 images processed
# 10420 images processed
# 10430 images processed
# 10440 images processed
# 10450 images processed
# 10460 images processed
# 10470 images processed
# 10480 images processed
# 10490 images processed
# 10500 images processed
# 10510 images processed
# 10520 images processed
# 10530 images processed
# 10540 images processed
# 10550 images processed
# 10560 images processed
# 10570 images processed
# 10580 images processed
# 10590 images processed
# 10600 images processed
# 10610 images processed
# 10620 images processed
# 10630 images processed
# 10640 images processed
# 10650 images processed
# 10660 images processed
# 10670 images processed
# 10680 images processed
# 10690 images processed
# 10700 images processed
# 10710 images processed
# 10720 images processed
# 10730 images processed
# 10740 images processed
# 10750 images processed
# 10760 images processed
# 10770 images processed
# 10780 images processed
# 10790 images processed
# 10800 images processed
# 10810 images processed
# 10820 images processed
# 10830 images processed
# 10840 images processed
# 10850 images processed
# 10860 images processed
# 10870 images processed
# 10880 images processed
# 10890 images processed
# 10900 images processed
# 10910 images processed
# 10920 images processed
# 10930 images processed
# 10940 images processed
# 10950 images processed
# 10960 images processed
# 10970 images processed
# 10980 images processed
# 10990 images processed
# 11000 images processed
# 11010 images processed
# 11020 images processed
# 11030 images processed
# 11040 images processed
# 11050 images processed
# 11060 images processed
# 11070 images processed
# 11080 images processed
# 11090 images processed
# 11100 images processed
# 11110 images processed
# 11120 images processed
# 11130 images processed
# 11140 images processed
# 11150 images processed
# 11160 images processed
# 11170 images processed
# 11180 images processed
# 11190 images processed
# 11200 images processed
# 11210 images processed
# 11220 images processed
# 11230 images processed
# 11240 images processed
# 11250 images processed
# 11260 images processed
# 11270 images processed
# 11280 images processed
# 11290 images processed
# 11300 images processed
# 11310 images processed
# 11320 images processed
# 11330 images processed
# 11340 images processed
# 11350 images processed
# 11360 images processed
# 11370 images processed
# 11380 images processed
# 11390 images processed
# 11400 images processed
# 11410 images processed
# 11420 images processed
# 11430 images processed
# 11440 images processed
# 11450 images processed
# 11460 images processed
# 11470 images processed
# 11480 images processed
# 11490 images processed
# 11500 images processed
# 11510 images processed
# 11520 images processed
# 11530 images processed
# 11540 images processed
# 11550 images processed
# 11560 images processed
# 11570 images processed
# 11580 images processed
# 11590 images processed
# 11600 images processed
# 11610 images processed
# 11620 images processed
# 11630 images processed
# 11640 images processed
# 11650 images processed
# 11660 images processed
# 11670 images processed
# 11680 images processed
# 11690 images processed
# 11700 images processed
# 11710 images processed
# 11720 images processed
# 11730 images processed
# 11740 images processed
# 11750 images processed
# 11760 images processed
# 11770 images processed
# 11780 images processed
# 11790 images processed
# 11800 images processed
# 11810 images processed
# 11820 images processed
# 11830 images processed
# 11840 images processed
# 11850 images processed
# 11860 images processed
# 11870 images processed
# 11880 images processed
# 11890 images processed
# 11900 images processed
# 11910 images processed
# 11920 images processed
# 11930 images processed
# 11940 images processed
# 11950 images processed
# 11960 images processed
# 11970 images processed
# 11980 images processed
# 11990 images processed
# 12000 images processed
# 12010 images processed
# 12020 images processed
# 12030 images processed
# 12040 images processed
# 12050 images processed
# 12060 images processed
# 12070 images processed
# 12080 images processed
# 12090 images processed
# 12100 images processed
# 12110 images processed
# 12120 images processed
# 12130 images processed
# 12140 images processed
# 12150 images processed
# 12160 images processed
# 12170 images processed
# 12180 images processed
# 12190 images processed
# 12200 images processed
# 12210 images processed
# 12220 images processed
# 12230 images processed
# 12240 images processed
# 12250 images processed
# 12260 images processed
# 13990 images processed
# 14000 images processed
# 14010 images processed
# 14020 images processed
# 14030 images processed
# 14040 images processed
# 14050 images processed
# 14060 images processed
# 14070 images processed
# 14080 images processed
# 14090 images processed
# 14100 images processed
# 14110 images processed
# 14120 images processed
# 14130 images processed
# 14140 images processed
# 14150 images processed
# 14160 images processed
# 14170 images processed
# 14180 images processed
# 14190 images processed
# 14200 images processed
# 14210 images processed
# 14220 images processed
# 14230 images processed
# 14240 images processed
# 14250 images processed
# 14260 images processed
# 14270 images processed
# 14280 images processed
# 14290 images processed
# 14300 images processed
# 14310 images processed
# 14320 images processed
# 14330 images processed
# 14340 images processed
# 14350 images processed
# 14360 images processed
# 14370 images processed
# 14380 images processed
# 14390 images processed
# 14400 images processed
# 14410 images processed
# 14420 images processed
# 14430 images processed
# 14440 images processed
# 14450 images processed
# 14460 images processed
# 14470 images processed
# 14480 images processed
# 14490 images processed
# 14500 images processed
# 14510 images processed
# 14520 images processed
# 14530 images processed
# 14540 images processed
# 14550 images processed
# 14560 images processed
# 14570 images processed
# 14580 images processed
# 14590 images processed
# 14600 images processed
# 14610 images processed
# 14620 images processed
# 14630 images processed
# 14640 images processed
# 14650 images processed
# 14660 images processed
# 14670 images processed
# 14680 images processed
# 14690 images processed
# 14700 images processed
# 14710 images processed
# 14720 images processed
# 14730 images processed
# 14740 images processed
# 14750 images processed
# 14760 images processed
# 14770 images processed
# 14780 images processed
# 14790 images processed
# 14800 images processed
# 14810 images processed
# 14820 images processed
# 14830 images processed
# 14840 images processed
# 14850 images processed
# 14860 images processed
# 14870 images processed
# 14880 images processed
# 14890 images processed
# 14900 images processed
# 14910 images processed
# 14920 images processed
# 14930 images processed
# 14940 images processed
# 14950 images processed
# 14960 images processed
# 14970 images processed
# 14980 images processed
# 14990 images processed
# 15000 images processed
# 15010 images processed
# 15020 images processed
# 15030 images processed
# 15040 images processed
# 15050 images processed
# 15060 images processed
# 15070 images processed
# 15080 images processed
# 15090 images processed
# 15100 images processed
# 15110 images processed
# 15120 images processed
# 15130 images processed
# 15140 images processed
# 15150 images processed
# 15160 images processed
# 15170 images processed
# 15180 images processed
# 15190 images processed
# 15200 images processed
# 15210 images processed
# 15220 images processed
# 15230 images processed
# 15240 images processed
# 15250 images processed
# 15260 images processed
# 15270 images processed
# 15280 images processed
# 15290 images processed
# 15300 images processed
# 15310 images processed
# 15320 images processed
# 15330 images processed
# 15340 images processed
# 15350 images processed
# 15360 images processed
# 15370 images processed
# 15380 images processed
# 15390 images processed
# 15400 images processed
# 15410 images processed
# 15420 images processed
# 15430 images processed
# 15440 images processed
# 15450 images processed
# 15460 images processed
# 15470 images processed
# 15480 images processed
# 15490 images processed
# 15500 images processed
# 15510 images processed
# 15520 images processed
# 15530 images processed
# 15540 images processed
# 15550 images processed
# 15560 images processed
# 15570 images processed
# 15580 images processed
# 15590 images processed
# 15600 images processed
# 15610 images processed
# 15620 images processed
# 15630 images processed
# 15640 images processed
# 15650 images processed
# 15660 images processed
# 15670 images processed
# 15680 images processed
# 15690 images processed
# 15700 images processed
# 15710 images processed
# 15720 images processed
# 15730 images processed
# 15740 images processed
# 15750 images processed
# 15760 images processed
# 15770 images processed
# 15780 images processed
# 15790 images processed
# 15800 images processed
# 15810 images processed
# 15820 images processed
# 15830 images processed
# 15840 images processed
# 15850 images processed
# 15860 images processed
# 15870 images processed
# 15880 images processed
# 15890 images processed
# 15900 images processed
# 15910 images processed
# 15920 images processed
# 15930 images processed
# 15940 images processed
# 15950 images processed
# 15960 images processed
# 15970 images processed
# 15980 images processed
# 15990 images processed
# 16000 images processed
# 16010 images processed
# 16020 images processed
# 16030 images processed
# 16040 images processed
# 16050 images processed
# 16060 images processed
# 16070 images processed
# 16080 images processed
# 16090 images processed
# 16100 images processed
# 16110 images processed
# 16120 images processed
# 16130 images processed
# 16140 images processed
# 16150 images processed
# 16160 images processed
# 16170 images processed
# 16180 images processed
# 16190 images processed
# 16200 images processed
# 16210 images processed
# 16220 images processed
# 16230 images processed
# 16240 images processed
# 16250 images processed
# 16260 images processed
# 16270 images processed
# 16280 images processed
# 16290 images processed
# 16300 images processed
# 16310 images processed
# 16320 images processed
# 16330 images processed
# 16340 images processed
# 16350 images processed
# 16360 images processed
# 16370 images processed
# 16380 images processed
# 16390 images processed
# 16400 images processed
# 16410 images processed
# 16420 images processed
# 16430 images processed
# 16440 images processed
# 16450 images processed
# 16460 images processed
# 16470 images processed
# 16480 images processed
# 16490 images processed
# 16500 images processed
# 16510 images processed
# 16520 images processed
# 16530 images processed
# 16540 images processed
# 16550 images processed
# 16560 images processed
# 16570 images processed
# 16580 images processed
# 16590 images processed
# 16600 images processed
# 16610 images processed
# 16620 images processed
# 16630 images processed
# 16640 images processed
# 16650 images processed
# 16660 images processed
# 16670 images processed
# 16680 images processed
# 16690 images processed
# 16700 images processed
# 16710 images processed
# 16720 images processed
# 16730 images processed
# 16740 images processed
# 16750 images processed
# 16760 images processed
# 16770 images processed
# 16780 images processed
# 16790 images processed
# 16800 images processed
# 16810 images processed
# 16820 images processed
# 16830 images processed
# 16840 images processed
# 16850 images processed
# 16860 images processed
# 16870 images processed
# 16880 images processed
# 16890 images processed
# 16900 images processed
# 16910 images processed
# 16920 images processed
# 16930 images processed
# 16940 images processed
# 16950 images processed
# 16960 images processed
# 16970 images processed
# 16980 images processed
# 16990 images processed
# 17000 images processed
# 17010 images processed
# 17020 images processed
# 17030 images processed
# 17040 images processed
# 17050 images processed
# 17060 images processed
# 17070 images processed
# 17080 images processed
# 17090 images processed
# 17100 images processed
# 17110 images processed
# 17120 images processed
# 17130 images processed
# 17140 images processed
# 17150 images processed
# 17160 images processed
# 17170 images processed
# 17180 images processed
# 17190 images processed
# 17200 images processed
# 17210 images processed
# 17220 images processed
# 17230 images processed
# 17240 images processed
# 17250 images processed
# 17260 images processed
# 17270 images processed
# 17280 images processed
# 17290 images processed
# 17300 images processed
# 17310 images processed
# 17320 images processed
# 17330 images processed
# 17340 images processed
# 17350 images processed
# 17360 images processed
# 17370 images processed
# 17380 images processed
# 17390 images processed
# 17400 images processed
# 17410 images processed
# 17420 images processed
# 17430 images processed
# 19160 images processed
# 19170 images processed
# 19180 images processed
# 19190 images processed
# 19200 images processed
# 19210 images processed
# 19220 images processed
# 19230 images processed
# 19240 images processed
# 19250 images processed
# 19260 images processed
# 19270 images processed
# 19280 images processed
# 19290 images processed
# 19300 images processed
# 19310 images processed
# 19320 images processed
# 19330 images processed
# 19340 images processed
# 19350 images processed
# 19360 images processed
# 19370 images processed
# 19380 images processed
# 19390 images processed
# 19400 images processed
# 19410 images processed
# 19420 images processed
# 19430 images processed
# 19440 images processed
# 19450 images processed
# 19460 images processed
# 19470 images processed
# 19480 images processed
# 19490 images processed
# 19500 images processed
# 19510 images processed
# 19520 images processed
# 19530 images processed
# 19540 images processed
# 19550 images processed
# 19560 images processed
# 19570 images processed
# 19580 images processed
# 19590 images processed
# 19600 images processed
# 19610 images processed
# 19620 images processed
# 19630 images processed
# 19640 images processed
# 19650 images processed
# 19660 images processed
# 19670 images processed
# 19680 images processed
# 19690 images processed
# 19700 images processed
# 19710 images processed
# 19720 images processed
# 19730 images processed
# 19740 images processed
# 19750 images processed
# 19760 images processed
# 19770 images processed
# 19780 images processed
# 19790 images processed
# 19800 images processed
# 19810 images processed
# 19820 images processed
# 19830 images processed
# 19840 images processed
# 19850 images processed
# 19860 images processed
# 19870 images processed
# 19880 images processed
# 19890 images processed
# 19900 images processed
# 19910 images processed
# 19920 images processed
# 19930 images processed
# 19940 images processed
# 19950 images processed
# 19960 images processed
# 19970 images processed
# 19980 images processed
# 19990 images processed
# 20000 images processed
# 20010 images processed
# 20020 images processed
# 20030 images processed
# 20040 images processed
# 20050 images processed
# 20060 images processed
# 20070 images processed
# 20080 images processed
# 20090 images processed
# 20100 images processed
# 20110 images processed
# 20120 images processed
# 20130 images processed
# 20140 images processed
# 20150 images processed
# 20160 images processed
# 20170 images processed
# 20180 images processed
# 20190 images processed
# 20200 images processed
# 20210 images processed
# 20220 images processed
# 20230 images processed
# 20240 images processed
# 20250 images processed
# 20260 images processed
# 20270 images processed
# 20280 images processed
# 20290 images processed
# 20300 images processed
# 20310 images processed
# 20320 images processed
# 20330 images processed
# 20340 images processed
# 20350 images processed
# 20360 images processed
# 20370 images processed
# 20380 images processed
# 20390 images processed
# 20400 images processed
# 20410 images processed
# 20420 images processed
# 20430 images processed
# 20440 images processed
# 20450 images processed
# 20460 images processed
# 20470 images processed
# 20480 images processed
# 20490 images processed
# 20500 images processed
# 20510 images processed
# 20520 images processed
# 20530 images processed
# 20540 images processed
# 20550 images processed
# 20560 images processed
# 20570 images processed
# 20580 images processed
# 20590 images processed
# 20600 images processed
# 20610 images processed
# 20620 images processed
# 20630 images processed
# 20640 images processed
# 20650 images processed
# 20660 images processed
# 20670 images processed
# 20680 images processed
# 20690 images processed
# 20700 images processed
# 20710 images processed
# 20720 images processed
# 20730 images processed
# 20740 images processed
# 20750 images processed
# 20760 images processed
# 20770 images processed
# 20780 images processed
# 20790 images processed
# 20800 images processed
# 20810 images processed
# 20820 images processed
# 20830 images processed
# 20840 images processed
# 20850 images processed
# 20860 images processed
# 20870 images processed
# 20880 images processed
# 20890 images processed
# 20900 images processed
# 20910 images processed
# 20920 images processed
# 20930 images processed
# 20940 images processed
# 20950 images processed
# 20960 images processed
# 20970 images processed
# 20980 images processed
# 20990 images processed
# 21000 images processed
# 21010 images processed
# 21020 images processed
# 21030 images processed
# 21040 images processed
# 21050 images processed
# 21060 images processed
# 21070 images processed
# 21080 images processed
# 21090 images processed
# 21100 images processed
# 21110 images processed
# 21120 images processed
# 21130 images processed
# 21140 images processed
# 21150 images processed
# 21160 images processed
# 21170 images processed
# 21180 images processed
# 21190 images processed
# 21200 images processed
# 21210 images processed
# 21220 images processed
# 21230 images processed
# 21240 images processed
# 21250 images processed
# 21260 images processed
# 21270 images processed
# 21280 images processed
# 21290 images processed
# ...
# 43060 images processed
# 43070 images processed
# 43080 images processed
# 43090 images processed
# 43100 images processed
# 43110 images processed
# 43120 images processed
# 43130 images processed
# 43140 images processed
# 43150 images processed
# 43160 images processed
# 43170 images processed
# 43180 images processed
# 43190 images processed
# 43200 images processed
# 43210 images processed
# 43220 images processed
# 43230 images processed
# 43240 images processed
# 43250 images processed
# 43260 images processed
# 43270 images processed
# 43280 images processed
# 43290 images processed
# 43300 images processed
# 43310 images processed
# 43320 images processed
# 43330 images processed
# 43340 images processed
# 43350 images processed
# 43360 images processed
# 43370 images processed
# 43380 images processed
# 43390 images processed
# 43400 images processed
# 43410 images processed
# 43420 images processed
# 43430 images processed
# 43440 images processed
# 43450 images processed
# 43460 images processed
# 43470 images processed
# 43480 images processed
# 43490 images processed
# 43500 images processed
# 43510 images processed
# 43520 images processed
# 43530 images processed
# 43540 images processed
# 43550 images processed
# 43560 images processed
# 43570 images processed
# 43580 images processed
# 43590 images processed
# 43600 images processed
# 43610 images processed
# 43620 images processed
# 43630 images processed
# 43640 images processed
# 43650 images processed
# 43660 images processed
# 43670 images processed
# 43680 images processed
# 43690 images processed
# 43700 images processed
# 43710 images processed
# 43720 images processed
# 43730 images processed
# 43740 images processed
# 43750 images processed
# 43760 images processed
# 43770 images processed
# 43780 images processed
# 43790 images processed
# 43800 images processed
# 43810 images processed
# 43820 images processed
# 43830 images processed
# 43840 images processed
# 43850 images processed
# 43860 images processed
# 43870 images processed
# 43880 images processed
# 43890 images processed
# 43900 images processed
# 43910 images processed
# 43920 images processed
# 43930 images processed
# 43940 images processed
# 43950 images processed
# 43960 images processed
# 43970 images processed
# 43980 images processed
# 43990 images processed
# 44000 images processed
# 44010 images processed
# 44020 images processed
# 44030 images processed
# 44040 images processed
# 44050 images processed
# 44060 images processed
# 44070 images processed
# 44080 images processed
# 44090 images processed
# 44100 images processed
# 44110 images processed
# 44120 images processed
# 44130 images processed
# 44140 images processed
# 44150 images processed
# 44160 images processed
# 44170 images processed
# 44180 images processed
# 44190 images processed
# 44200 images processed
# 44210 images processed
# 44220 images processed
# 44230 images processed
# 44240 images processed
# 44250 images processed
# 44260 images processed
# 44270 images processed
# 44280 images processed
# 44290 images processed
# 44300 images processed
# 44310 images processed
# 44320 images processed
# 44330 images processed
# 44340 images processed
# 44350 images processed
# 44360 images processed
# 44370 images processed
# 44380 images processed
# 44390 images processed
# 44400 images processed
# 44410 images processed
# 44420 images processed
# 44430 images processed
# 44440 images processed
# 44450 images processed
# 44460 images processed
# 44470 images processed
# 44480 images processed
# 44490 images processed
# 44500 images processed
# 44510 images processed
# 44520 images processed
# 44530 images processed
# 44540 images processed
# 44550 images processed
# 44560 images processed
# 44570 images processed
# 44580 images processed
# 44590 images processed
# 44600 images processed
# 44610 images processed
# 44620 images processed
# 44630 images processed
# 44640 images processed
# 44650 images processed
# 44660 images processed
# 44670 images processed
# 44680 images processed
# 44690 images processed
# 44700 images processed
# 44710 images processed
# 44720 images processed
# 44730 images processed
# 44740 images processed
# 44750 images processed
# 44760 images processed
# 44770 images processed
# 44780 images processed
# 44790 images processed
# 44800 images processed
# 44810 images processed
# 44820 images processed
# 44830 images processed
# 44840 images processed
# 44850 images processed
# 44860 images processed
# 44870 images processed
# 44880 images processed
# 44890 images processed
# 44900 images processed
# 44910 images processed
# 44920 images processed
# 44930 images processed
# 44940 images processed
# 44950 images processed
# 44960 images processed
# 44970 images processed
# 44980 images processed
# 44990 images processed
# 45000 images processed
# 45010 images processed
# 45020 images processed
# 45030 images processed
# 45040 images processed
# 45050 images processed
# 45060 images processed
# 45070 images processed
# 45080 images processed
# 45090 images processed
# 45100 images processed
# 45110 images processed
# 45120 images processed
# 45130 images processed
# 45140 images processed
# 45150 images processed
# 45160 images processed
# 45170 images processed
# 45180 images processed
# 45190 images processed
# 45200 images processed
# 45210 images processed
# 45220 images processed
# 45230 images processed
# 45240 images processed
# 45250 images processed
# 45260 images processed
# 45270 images processed
# 45280 images processed
# 45290 images processed
# 45300 images processed
# 45310 images processed
# 45320 images processed
# 45330 images processed
# 45340 images processed
# 45350 images processed
# 45360 images processed
# 45370 images processed
# 45380 images processed
# 45390 images processed
# 45400 images processed
# 45410 images processed
# 45420 images processed
# 45430 images processed
# 45440 images processed
# 45450 images processed
# 45460 images processed
# 45470 images processed
# 45480 images processed
# 45490 images processed
# 45500 images processed
# 45510 images processed
# 45520 images processed
# 45530 images processed
# 45540 images processed
# 45550 images processed
# 45560 images processed
# 45570 images processed
# 45580 images processed
# 45590 images processed
# 45600 images processed
# 45610 images processed
# 45620 images processed
# 45630 images processed
# 45640 images processed
# 45650 images processed
# 45660 images processed
# 45670 images processed
# 45680 images processed
# 45690 images processed
# 45700 images processed
# 45710 images processed
# 45720 images processed
# 45730 images processed
# 45740 images processed
# 45750 images processed
# 45760 images processed
# 45770 images processed
# 45780 images processed
# 45790 images processed
# 45800 images processed
# 45810 images processed
# 45820 images processed
# 45830 images processed
# 45840 images processed
# 45850 images processed
# 45860 images processed
# 45870 images processed
# 45880 images processed
# 45890 images processed
# 45900 images processed
# 45910 images processed
# 45920 images processed
# 45930 images processed
# 45940 images processed
# 45950 images processed
# 45960 images processed
# 45970 images processed
# 45980 images processed
# 45990 images processed
# 46000 images processed
# 46010 images processed
# 46020 images processed
# 46030 images processed
# 46040 images processed
# 46050 images processed
# 46060 images processed
# 46070 images processed
# 47810 images processed
# 47820 images processed
# 47830 images processed
# 47840 images processed
# 47850 images processed
# 47860 images processed
# 47870 images processed
# 47880 images processed
# 47890 images processed
# 47900 images processed
# 47910 images processed
# 47920 images processed
# 47930 images processed
# 47940 images processed
# 47950 images processed
# 47960 images processed
# 47970 images processed
# 47980 images processed
# 47990 images processed
# 48000 images processed
# 48010 images processed
# 48020 images processed
# 48030 images processed
# 48040 images processed
# 48050 images processed
# 48060 images processed
# 48070 images processed
# 48080 images processed
# 48090 images processed
# 48100 images processed
# 48110 images processed
# 48120 images processed
# 48130 images processed
# 48140 images processed
# 48150 images processed
# 48160 images processed
# 48170 images processed
# 48180 images processed
# 48190 images processed
# 48200 images processed
# 48210 images processed
# 48220 images processed
# 48230 images processed
# 48240 images processed
# 48250 images processed
# 48260 images processed
# 48270 images processed
# 48280 images processed
# 48290 images processed
# 48300 images processed
# 48310 images processed
# 48320 images processed
# 48330 images processed
# 48340 images processed
# 48350 images processed
# 48360 images processed
# 48370 images processed
# 48380 images processed
# 48390 images processed
# 48400 images processed
# 48410 images processed
# 48420 images processed
# 48430 images processed
# 48440 images processed
# 48450 images processed
# 48460 images processed
# 48470 images processed
# 48480 images processed
# 48490 images processed
# 48500 images processed
# 48510 images processed
# 48520 images processed
# 48530 images processed
# 48540 images processed
# 48550 images processed
# 48560 images processed
# 48570 images processed
# 48580 images processed
# 48590 images processed
# 48600 images processed
# 48610 images processed
# 48620 images processed
# 48630 images processed
# 48640 images processed
# 48650 images processed
# 48660 images processed
# 48670 images processed
# 48680 images processed
# 48690 images processed
# 48700 images processed
# 48710 images processed
# 48720 images processed
# 48730 images processed
# 48740 images processed
# 48750 images processed
# 48760 images processed
# 48770 images processed
# 48780 images processed
# 48790 images processed
# 48800 images processed
# 48810 images processed
# 48820 images processed
# 48830 images processed
# 48840 images processed
# 48850 images processed
# 48860 images processed
# 48870 images processed
# 48880 images processed
# 48890 images processed
# 48900 images processed
# 48910 images processed
# 48920 images processed
# 48930 images processed
# 48940 images processed
# 48950 images processed
# 48960 images processed
# 48970 images processed
# 48980 images processed
# 48990 images processed
# 49000 images processed
# 49010 images processed
# 49020 images processed
# 49030 images processed
# 49040 images processed
# 49050 images processed
# 49060 images processed
# 49070 images processed
# 49080 images processed
# 49090 images processed
# 49100 images processed
# 49110 images processed
# 49120 images processed
# 49130 images processed
# 49140 images processed
# 49150 images processed
# 49160 images processed
# 49170 images processed
# 49180 images processed
# 49190 images processed
# 49200 images processed
# 49210 images processed
# 49220 images processed
# 49230 images processed
# 49240 images processed
# 49250 images processed
# 49260 images processed
# 49270 images processed
# 49280 images processed
# 49290 images processed
# 49300 images processed
# 49310 images processed
# 49320 images processed
# 49330 images processed
# 49340 images processed
# 49350 images processed
# 49360 images processed
# 49370 images processed
# 49380 images processed
# 49390 images processed
# 49400 images processed
# 49410 images processed
# 49420 images processed
# 49430 images processed
# 49440 images processed
# 49450 images processed
# 49460 images processed
# 49470 images processed
# 49480 images processed
# 49490 images processed
# 49500 images processed
# 49510 images processed
# 49520 images processed
# 49530 images processed
# 49540 images processed
# 49550 images processed
# 49560 images processed
# 49570 images processed
# 49580 images processed
# 49590 images processed
# 49600 images processed
# 49610 images processed
# 49620 images processed
# 49630 images processed
# 49640 images processed
# 49650 images processed
# 49660 images processed
# 49670 images processed
# 49680 images processed
# 49690 images processed
# 49700 images processed
# 49710 images processed
# 49720 images processed
# 49730 images processed
# 49740 images processed
# 49750 images processed
# 49760 images processed
# 49770 images processed
# 49780 images processed
# 49790 images processed
# 49800 images processed
# 49810 images processed
# 49820 images processed
# 49830 images processed
# 49840 images processed
# 49850 images processed
# 49860 images processed
# 49870 images processed
# 49880 images processed
# 49890 images processed
# 49900 images processed
# 49910 images processed
# 49920 images processed
# 49930 images processed
# 49940 images processed
# 49950 images processed
# 49960 images processed
# 49970 images processed
# 49980 images processed
# 49990 images processed
# 50000 images processed

# %%
# write codes to file
with open('codes', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %% [markdown]
# ## Building the Classifier
#
# Now that we have codes for all the images, we can build a simple classifier on top of them. The codes behave just like normal input into a simple neural network. Below I'm going to have you do most of the work.

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %% [markdown]
# ### Data prep
#
# As usual, now we need to one-hot encode our labels and create validation/test sets. First up, creating our labels!
#
# > **Exercise:** From scikit-learn, use [LabelBinarizer](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html) to create one-hot encoded vectors from the labels.

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
lb.fit(labels)

labels_vecs = lb.transform(labels)

# %% [markdown]
# Now you'll want to create your training, validation, and test sets. An important thing to note here is that our labels and data aren't randomized yet. We'll want to shuffle our data so the validation and test sets contain data from all classes. Otherwise, you could end up with testing sets that are all one class. Typically, you'll also want to make sure that each smaller set has the same the distribution of classes as it is for the whole data set. The easiest way to accomplish both these goals is to use [`StratifiedShuffleSplit`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) from scikit-learn.
#
# You can create the splitter like so:
# ```
# ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
# ```
# Then split the data with
# ```
# splitter = ss.split(x, y)
# ```
#
# `ss.split` returns a generator of indices. You can pass the indices into the arrays to get the split sets. The fact that it's a generator means you either need to iterate over it, or use `next(splitter)` to get the indices. Be sure to read the [documentation](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) and the [user guide](http://scikit-learn.org/stable/modules/cross_validation.html#random-permutations-cross-validation-a-k-a-shuffle-split).
#
# > **Exercise:** Use StratifiedShuffleSplit to split the codes and labels into training, validation, and test sets.

# %%
from sklearn.model_selection import StratifiedShuffleSplit

ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

train_idx, val_idx = next(ss.split(codes, labels))

half_val_len = int(len(val_idx)/2)
val_idx, test_idx = val_idx[:half_val_len], val_idx[half_val_len:]

train_x, train_y = codes[train_idx], labels_vecs[train_idx]
val_x, val_y = codes[val_idx], labels_vecs[val_idx]
test_x, test_y = codes[test_idx], labels_vecs[test_idx]

# %%
print("Train shapes (x, y):", train_x.shape, train_y.shape)
print("Validation shapes (x, y):", val_x.shape, val_y.shape)
print("Test shapes (x, y):", test_x.shape, test_y.shape)
# Out:
# Train shapes (x, y): (40000, 4096) (40000, 10)
# Validation shapes (x, y): (5000, 4096) (5000, 10)
# Test shapes (x, y): (5000, 4096) (5000, 10)

# %% [markdown]
# If you did it right, you should see these sizes for the training sets:
#
# ```
# Train shapes (x, y): (2936, 4096) (2936, 5)
# Validation shapes (x, y): (367, 4096) (367, 5)
# Test shapes (x, y): (367, 4096) (367, 5)
# ```

# %% [markdown]
# ### Classifier layers
#
# Once you have the convolutional codes, you just need to build a classfier from some fully connected layers. You use the codes as the inputs and the image labels as targets. Otherwise the classifier is a typical neural network.
#
# > **Exercise:** With the codes and labels loaded, build the classifier. Consider the codes as your inputs, each of them are 4096D vectors. You'll want to use a hidden layer and an output layer as your classifier. Remember that the output layer needs to have one unit for each class and a softmax activation function. Use the cross entropy to calculate the cost.

# %%
inputs_ = tf.placeholder(tf.float32, shape=[None, codes.shape[1]])
labels_ = tf.placeholder(tf.int64, shape=[None, labels_vecs.shape[1]])

fc = tf.contrib.layers.fully_connected(inputs_, 256)
    
logits = tf.contrib.layers.fully_connected(fc, labels_vecs.shape[1], activation_fn=None)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=labels_, logits=logits)
cost = tf.reduce_mean(cross_entropy)

optimizer = tf.train.AdamOptimizer().minimize(cost)

predicted = tf.nn.softmax(logits)
correct_pred = tf.equal(tf.argmax(predicted, 1), tf.argmax(labels_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# ### Batches!
#
# Here is just a simple way to do batches. I've written it so that it includes all the data. Sometimes you'll throw out some data at the end to make sure you have full batches. Here I just extend the last batch to include the remaining data.

# %%
def get_batches(x, y, n_batches=10):
    """ Return a generator that yields batches from arrays x and y. """
    batch_size = len(x)//n_batches
    
    for ii in range(0, n_batches*batch_size, batch_size):
        # If we're not on the last batch, grab data with size batch_size
        if ii != (n_batches-1)*batch_size:
            X, Y = x[ii: ii+batch_size], y[ii: ii+batch_size] 
        # On the last batch, grab the rest of the data
        else:
            X, Y = x[ii:], y[ii:]
        # I love generators
        yield X, Y

# %% [markdown]
# ### Training
#
# Here, we'll train the network.
#
# > **Exercise:** So far we've been providing the training code for you. Here, I'm going to give you a bit more of a challenge and have you write the code to train the network. Of course, you'll be able to see my solution if you need help.

# %%
epochs = 75
iteration = 0
saver = tf.train.Saver()
with tf.Session() as sess:
    
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for x, y in get_batches(train_x, train_y):
            feed = {inputs_: x,
                    labels_: y}
            loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            print("Epoch: {}/{}".format(e+1, epochs),
                  "Iteration: {}".format(iteration),
                  "Training loss: {:.5f}".format(loss))
            iteration += 1
            
            if iteration % 5 == 0:
                feed = {inputs_: val_x,
                        labels_: val_y}
                val_acc = sess.run(accuracy, feed_dict=feed)
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "
# Epoch: 73/75 Iteration: 723 Training loss: 0.01382
# Epoch: 73/75 Iteration: 724 Training loss: 0.01352
# Epoch: 72/75 Iteration: 725 Validation Acc: 0.8612
# Epoch: 73/75 Iteration: 725 Training loss: 0.01262
# Epoch: 73/75 Iteration: 726 Training loss: 0.01306
# Epoch: 73/75 Iteration: 727 Training loss: 0.01278
# Epoch: 73/75 Iteration: 728 Training loss: 0.01420
# Epoch: 73/75 Iteration: 729 Training loss: 0.01546
# Epoch: 72/75 Iteration: 730 Validation Acc: 0.8596
# Epoch: 74/75 Iteration: 730 Training loss: 0.01450
# Epoch: 74/75 Iteration: 731 Training loss: 0.01343
# Epoch: 74/75 Iteration: 732 Training loss: 0.01371
# Epoch: 74/75 Iteration: 733 Training loss: 0.01270
# Epoch: 74/75 Iteration: 734 Training loss: 0.01221
# Epoch: 73/75 Iteration: 735 Validation Acc: 0.8606
# Epoch: 74/75 Iteration: 735 Training loss: 0.01161
# Epoch: 74/75 Iteration: 736 Training loss: 0.01219
# Epoch: 74/75 Iteration: 737 Training loss: 0.01223
# Epoch: 74/75 Iteration: 738 Training loss: 0.01339
# Epoch: 74/75 Iteration: 739 Training loss: 0.01444
# Epoch: 73/75 Iteration: 740 Validation Acc: 0.8606
# Epoch: 75/75 Iteration: 740 Training loss: 0.01357
# Epoch: 75/75 Iteration: 741 Training loss: 0.01244
# Epoch: 75/75 Iteration: 742 Training loss: 0.01288
# Epoch: 75/75 Iteration: 743 Training loss: 0.01187
# Epoch: 75/75 Iteration: 744 Training loss: 0.01166
# Epoch: 74/75 Iteration: 745 Validation Acc: 0.8624
# Epoch: 75/75 Iteration: 745 Training loss: 0.01100
# Epoch: 75/75 Iteration: 746 Training loss: 0.01146
# Epoch: 75/75 Iteration: 747 Training loss: 0.01125
# Epoch: 75/75 Iteration: 748 Training loss: 0.01237
# Epoch: 75/75 Iteration: 749 Training loss: 0.01353
# Epoch: 74/75 Iteration: 750 Validation Acc: 0.8612

# %% [markdown]
# ### Testing
#
# Below you see the test accuracy. You can also see the predictions returned for images.

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: test_x,
            labels_: test_y}
    test_acc = sess.run(accuracy, feed_dict=feed)
    print("Test accuracy: {:.4f}".format(test_acc))
# Out:
# Test accuracy: 0.8384

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from scipy.ndimage import imread

# %% [markdown]
# Below, feel free to choose images and see how the trained classifier predicts the flowers in them.

# %%
test_img_path = 'flower_photos/roses/10894627425_ec76bbc757_n.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)

# %%
# Run this cell if you don't have a vgg graph built
with tf.Session() as sess:
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    vgg = vgg16.Vgg16()
    vgg.build(input_)

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(5), prediction)
_ = plt.yticks(np.arange(5), lb.classes_)
